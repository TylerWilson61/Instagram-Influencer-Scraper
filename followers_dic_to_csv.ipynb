# %%
import pandas as pd
import json

# %%
with open ('array_of_followers','r') as file:
    dic = json.loads(file.read())
df = pd.DataFrame.from_dict(dic)
df
# Out:
#               usernames influencer_status  \
# 0         imma_moves_qi                na
# 1            anushka711                na
# 2             taycolbar                na
# 3     blossomwellnessco                na
# 4       jordynriver1776                na
# ...                 ...               ...
# 8347           deny4077                na
# 8348    maria_unicornzz                na
# 8349  biohackingsecrets        influencer
# 8350           sassilly                na
# 8351   biocurious_kayla        influencer
#
#                                                     bio
# 0     ∞ Facilitator \nTransformative healing using h...
# 1                           🌵 @iheartradio @iheartmedia
# 2
# 3     mind • memory • mood \n🌻 live life in full blo...
# 4     Made in America 🇺🇸\nJuris Doctor Candidate \n✝...
# ...                                                 ...
# 8347
# 8348                                                  🤪
# ...

# %%
df2 = df.loc[df['influencer_status'] == 'influencer']
df2
# Out:
#                usernames influencer_status  \
# 47       thediamondboss_        influencer
# 70             tia__0224        influencer
# 71    veganbeautybabe.xo        influencer
# 77              drdemeri        influencer
# 101          ruqayakalla        influencer
# ...                  ...               ...
# 8232   oliviakreigenfeld        influencer
# 8243       skyegallagher        influencer
# 8316       whirlwind1080        influencer
# 8349   biohackingsecrets        influencer
# 8351    biocurious_kayla        influencer
#
#                                                     bio
# 47    👩🏽‍🔬 Neuroscientist  \n ___\n    \n \n@neuroat...
# 70    mama to the cutest little boy! • wv • snapchat...
# 71    🐾 dog mom ♡ baby boy on the way! 🍼👼🏼\n💓 LOVE i...
# 77    Leading #Fertility #Thyroid #Hormones Eggspurt...
# 101   ♾Evolving Through Consciousness-Intuitive Holi...
# ...                                                 ...
# ...

# %%
influencer_followers_csv = df.to_csv(r"/users/tylerwilson/desktop/formula/insta-all-followers.csv",index=False)

# %%
influencer_followers_csv = df2.to_csv(r"/users/tylerwilson/desktop/formula/insta-influencers.csv",index=False)
